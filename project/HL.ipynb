# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import pytesseract
import numpy as np
from PIL import Image
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %% [markdown]
# # 이미지 사이즈 변경 fx fy : 배수
# ```
# gray=cv2.resize(gray, dsize=(0,0), fx=4,fy=4)
# print(gray.shape)
# ```

# %%
img=cv2.imread('video/image (3).jpg')

# %%
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
score=img[:25,1555:1620]
plt.imshow(score)
cv2.imwrite('score.jpg',score)
str_score = pytesseract.image_to_string(score)
print(str_score)
# Out:
# since

# %%
kda=img[:25,1665:1710]
plt.imshow(kda)
cv2.imwrite('kda.jpg',kda)
str_kda = pytesseract.image_to_string(kda, config='outputbase digits')
print(str_kda)

# %%
time=img[:25,1860:1905]
plt.imshow(time)
cv2.imwrite('time.jpg',time)
str_time = pytesseract.image_to_string(time, config='outputbase digits')
print(str_time)

# %%
kda2 = cv2.imread('kda2.jpg',0)
# plt.imshow(kda2)
img_blur = cv2.GaussianBlur(kda2, (3,3), 0)
_, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.imshow(binary)

kda2_str = pytesseract.image_to_string(binary)
print(kda2_str)
# Out:
# CA

# %%
kda2 = cv2.imread('kda2.jpg',0)
# plt.imshow(kda2)
img_blur = cv2.GaussianBlur(kda2, (3,3), 0)
_, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)


plt.imshow(binary)

kda2_str = pytesseract.image_to_string(kda2)
print(kda2_str)
# Out:
# 4/3/1

# %%
kda2 = cv2.imread('time2.jpg',0)
# plt.imshow(kda2)

img_blur = cv2.GaussianBlur(kda2, (3,3), 0)
_, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(binary)

kda2_str = pytesseract.image_to_string(binary)
print(kda2_str)
# Out:
# 16:56

# %%
kda2 = cv2.imread('score2.jpg',0)
# plt.imshow(kda2)

img_blur = cv2.GaussianBlur(kda2, (3,3), 0)
_, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(binary)

kda2_str = pytesseract.image_to_string(binary)
print(kda2_str)
# Out:
# 15 vs 14

# %%
board=img[:25,1555:1905]
# plt.imshow(board)
print(board.shape)
# Out:
# (25, 350, 3)

# %%
gray = cv2.cvtColor(board, cv2.COLOR_BGR2GRAY)
# kda2 = cv2.imread('score2.jpg',0)
# plt.imshow(kda2)
# plt.imshow(gray)
gray=cv2.resize(gray, dsize=(0,0), fx=4,fy=4)
print(gray.shape)

# img_blur = cv2.GaussianBlur(gray, (3,3), 0)
# _, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(gray)

kda2_str = pytesseract.image_to_string(gray)
print(kda2_str)
# Out:
# (100, 1400)
# et ¥ 0/0/0 rer ome

# %%
score=img[:25,1555:1620]
score=cv2.resize(score, dsize=(0,0), fx=4,fy=4)
plt.imshow(score)
cv2.imwrite('score.jpg',score)
str_score = pytesseract.image_to_string(score)
print(str_score)
# Out:
# WA

# %%
kda=img[0:25,1663:1713]
gray = cv2.cvtColor(kda, cv2.COLOR_RGB2GRAY)
score=cv2.resize(gray, dsize=(0,0), fx=5,fy=5)

img_blur = cv2.GaussianBlur(score, (3,3), 0)
_, binary = cv2.threshold(score, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.imshow(binary)

kda2_str = pytesseract.image_to_string(binary)
print(kda2_str)
# Out:
# oy /ey/e)

# %%
score=img[:25,1555:1620]
gray = cv2.cvtColor(score, cv2.COLOR_RGB2GRAY)
score=cv2.resize(gray, dsize=(0,0), fx=5,fy=5)

img_blur = cv2.GaussianBlur(score, (3,3), 0)
_, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(binary)

str_score = pytesseract.image_to_string(binary)
print(str_score)
# Out:
# Nw

# %%
time=img[:25,1860:1905]
gray = cv2.cvtColor(time, cv2.COLOR_RGB2GRAY)
score=cv2.resize(gray, dsize=(0,0), fx=5,fy=5)

img_blur = cv2.GaussianBlur(score, (3,3), 0)
_, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(binary)

str_score = pytesseract.image_to_string(binary)
print(str_score)
# Out:
# 05:17

# %%
board=img[:25,1555:1905]
gray = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)

img_blur = cv2.GaussianBlur(gray, (3,3), 0)
_, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

score=cv2.resize(binary, dsize=(0,0), fx=5,fy=5)


plt.imshow(score)

str_score = pytesseract.image_to_string(score)
print(str_score)
# Out:
# ara
#
# PU
#
# PY |
#
# Cee rer

# %%
board=img[:25,1555:1905]
gray = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)

score=cv2.resize(gray, dsize=(0,0), fx=5,fy=5)

img_blur = cv2.GaussianBlur(score, (3,3), 0)
_, binary = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.imshow(binary)

str_score = pytesseract.image_to_string(binary)
print(str_score)
# Out:
# Ly ¥ 0/0/0 yey) Cetera)

# %%
for i in range(1,29):
    filename = 'video/image ('+str(i)+').jpg'
    img=cv2.imread(filename)
#     cv2.imwrite('asdddd.jpg',img)
    board=img[:25,1550:1905]
    gray = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)

    fx=4
    fy=4

    board=cv2.resize(gray, dsize=(0,0), fx=fx,fy=fy)

    img_blur = cv2.GaussianBlur(board, (3,3), 0)
    _, board = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    # plt.imshow(board)

    length = board.shape[1]
    # print(length)

    score = board[:,5:int(length*0.21)]
    # kernel = np.ones((3,3), np.uint8)
    # closing = cv2.morphologyEx(score, cv2.MORPH_CLOSE, kernel, iterations=2)
    # plt.imshow(score)
    str_score = pytesseract.image_to_string(score)
    print(str_score)

    kda = board[:,int(length*0.32):int(length*0.48)]
    # plt.imshow(kda)

    str_score = pytesseract.image_to_string(kda)
    print(str_score)

    time = board[:,int(length*0.87):]
    # plt.imshow(time)
    plt.imshow(np.hstack((score,kda,time)))

    str_score = pytesseract.image_to_string(time)
    print(str_score)
    print('')
# Out:
# -é yg 23
# 8/5/5
# 27:16
#
# vg?
# 0/0/0
# 04:54
#
# Ave?
# 0/0/0
# 05:15
#
# ‘ivsZ2
# 0/1/0
# 05:39
#
# i vs2
# 0/1/0
# 06:06
#
# ms 2
# _
# 0/1/0
# 06:39
#
# "vs2
# 0/1/0
# 06:42
#
# ‘v5?
# 0/1/0
# 07:59
#
# Svs 4
# 1/1/0
# 08:52
#
# ‘ys J
# 1/1/0
# 10:14
#
# cvs /
# 1/1/0
# 10:40
#
# us]
# 1/1/0
# 11:11
#
# os J
# 1/1/0
# 11:52
#
# os J
# 1/1/0
# 11:52
#
# tived
# 2/1/1
# 13:39
#
# tived
# 2/1/1
# 13:39
#
# oye 14
# 4/3/1
# 16:06
#
# oye 14
# 4/3/1
# 16:06
#
# ove 14
# 4/3/1
# 17:07
#
# ‘v6 18
# 8/3/1
# 17:34
#
# v5 18
# 8/3/1
# 18:10
#
# v5 18
# 8/3/1
# 18:10
#
# / vg 18
# 8/3/1
# 19:48
#
# / vg 18
# 8/3/1
# 19:48
#
# v6 19
# 8/4/2
# 21:44
#
# v6 19
# 8/4/2
# 21:44
#
# vive 22
# 8/5/4
# 23:24
#
# vive 22
# 8/5/4
# 23:24

# %%
color = [255, 0, 0]
pixel = np.uint8([[color]])

hsv = cv2.cvtColor(pixel, cv2.COLOR_BGR2HSV)
hsv = hsv[0][0]


print("bgr: ", color)
print("hsv: ", hsv)
# Out:
# bgr:  [255, 0, 0]
# hsv:  [120 255 255]

# %%
img_color = cv2.imread('video/image (4).jpg')

board=img_color[:25,1550:1905]
score = board[:,5:int(length*0.21)]

height,width = score.shape[:2]

img_hsv = cv2.cvtColor(score, cv2.COLOR_BGR2HSV)


lower_blue = (120-10, 10, 10)
upper_blue = (120+10, 255, 255)
img_mask = cv2.inRange(img_hsv, lower_blue, upper_blue)


img_result = cv2.bitwise_and(score, score, mask = img_mask)


cv2.imshow('img_color', score)
cv2.imshow('img_mask', img_mask)
cv2.imshow('img_result', img_result)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for i in range(1,29):
    filename = 'video/image ('+str(i)+').jpg'
    img=cv2.imread(filename)
#     cv2.imwrite('asdddd.jpg',img)
    board=img[:25,1550:1905]
    gray = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)

    fx=4
    fy=4

    board=cv2.resize(gray, dsize=(0,0), fx=fx,fy=fy)

    img_blur = cv2.GaussianBlur(board, (3,3), 0)
    _, board = cv2.threshold(img_blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    # plt.imshow(board)

    length = board.shape[1]
    # print(length)

    board = np.hstack([board[:,5:int(length*0.21)],board[:,int(length*0.32):int(length*0.48)],board[:,int(length*0.87):]])
    str_board = pytesseract.image_to_string(board)
    print(str_board)
# Out:
# ~/vg23 8/5/5 27:16
# vs2  O/0/0 04:54
# Avs2  0/0/0 05:15
# ‘vs2  0/1/0 05:39
# vs2  0/1/0 06:06
# mVs2 0/1/0 06:39
# —lye2 0/1/0 06:42
# ‘vs2  0/1/0 07:59
# ’vs4  1/1/0 08:52
# ‘'vs/7 1/1/0 10:14
# “vs/ 1/1/0 10:40
# vvsF 1/1/0 11:11
# vs/ 1/1/0 11:52
# vs/ 1/1/0 11:52
# tiveY 2/1/1 13:39
# tiveY 2/1/1 13:39
# ‘vs 14 4/3/1 16:06
# ‘vs 14 4/3/1 16:06
# vs 14 4/3/1 17:07
# '¢.vs 18 8/3/1 17:34
# vs 18 8/3/1 18:10
# vs 18 8/3/1 18:10
# ~' vs 18 8/3/1 19:48
# ~' vs 18 8/3/1 19:48
# » vs 19 8/4/2 21:44
# » vs 19 8/4/2 21:44
# Yévg22 8/5/4 23:24
# Yévg22 8/5/4 23:24

# %%
filename = 'video/image (3).jpg'
img=cv2.imread(filename)
#     cv2.imwrite('asdddd.jpg',img)
board=img[:25,1550:1905]

board = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)

fx=4
fy=4

board=cv2.resize(board, dsize=(0,0), fx=fx,fy=fy)

# kernel = np.ones((3,3),np.uint8)
# para1 : 이미지, para2 : 함수 이용, para3 : 커널
# board = cv2.morphologyEx(board, cv2.MORPH_GRADIENT, kernel)
# board = cv2.adaptiveThreshold(board, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 13, 5)

# board = cv2.morphologyEx(board, cv2.MORPH_OPEN, kernel, iterations=1)
# board = cv2.morphologyEx(board, cv2.MORPH_CLOSE, kernel,iterations=5)
# board = cv2.dilate(board,kernel,iterations = 3)

# kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
# board = cv2.filter2D(board, -1, kernel)

board = cv2.GaussianBlur(board, (3,3), 0)
_, board = cv2.threshold(board, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
# plt.imshow(board)

# board = cv2.Canny(board, 50, 200) 

length = board.shape[1]
board=board[:,5:int(length*0.21)]
plt.imshow(board)
# plt.hist(board.ravel(), int(length*0.21), [0, int(length*0.21)], color='black')
# plt.show()
str_board = pytesseract.image_to_string(board)
print(str_board)
# Out:
# Ave?

# %%
for i in range(1,29):
    filename = 'video/image ('+str(i)+').jpg'
    img=cv2.imread(filename)
    #     cv2.imwrite('asdddd.jpg',img)
    board=img[:25,1550:1905]
    length = board.shape[1]
    board=board[:,5:int(length*0.21)]
    board = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)

    fx=4
    fy=4

    board=cv2.resize(board, dsize=(0,0), fx=fx,fy=fy)

    # kernel = np.ones((3,3),np.uint8)
    # para1 : 이미지, para2 : 함수 이용, para3 : 커널
    # board = cv2.morphologyEx(board, cv2.MORPH_GRADIENT, kernel)
    # board = cv2.adaptiveThreshold(board, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 13, 5)

    
    # board = cv2.morphologyEx(board, cv2.MORPH_CLOSE, kernel,iterations=5)
    # board = cv2.dilate(board,kernel,iterations = 3)

    # kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
    # board = cv2.filter2D(board, -1, kernel)

    board = cv2.GaussianBlur(board, (3,3), 0)
    _, board = cv2.threshold(board, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    board = cv2.morphologyEx(board, cv2.MORPH_OPEN, kernel, iterations=1)
    # plt.imshow(board)

    # board = cv2.Canny(board, 50, 200) 



#     plt.imshow(board)
    str_board = pytesseract.image_to_string(board)
    print(str_board)
# Out:
# Avs2
# Avs2
# Ovs2
# ivs2
# rvs
#
# Cvs
# ivs4
# 9vs7
# 9vs/
# Gvus/
# Qvs/
# Qvs/
# lO vs9
# lO vs9
# 15 vs 14
# 15 vs 14
# iuvs14
# 16 vs 18
# 16 vs 18
# 16 vs 18
# 1/7 vs 18
# 1/7 vs 18
# Zi vs 19
# Zi vs 19
# 26 vs 22
# 26 vs 22

# %%
filename = 'video/image (8).jpg'
total = []

img=cv2.imread(filename)

#     cv2.imwrite('asdddd.jpg',img)
board=img[:25,1550:1905]
length = board.shape[1]
board=board[:,5:int(length*0.21)]

fx=4
fy=4
board=cv2.resize(board, dsize=(0,0), fx=fx,fy=fy)
board = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)
total.append(board)
board = cv2.GaussianBlur(board, (3, 3), 0)
total.append(board)
_, board = cv2.threshold(board, 60, 255, cv2.THRESH_BINARY)
total.append(board)
plt.imshow(np.hstack(total))
str_board = pytesseract.image_to_string(board)
print(str_board)
# Out:
# Svs2

# %%
filename = 'video/image (2).jpg'
total = []

img=cv2.imread(filename)

#     cv2.imwrite('asdddd.jpg',img)
board=img[:25,1550:1905]
length = board.shape[1]
board=board[:,5:int(length*0.21)]
plt.imshow(board)
plt.show()
print('basic')
plt.hist(board.ravel(), 256, [0, 256], color='black')
plt.show()

fx=4
fy=4
board=cv2.resize(board, dsize=(0,0), fx=fx,fy=fy)
board = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)
print('gray')
plt.hist(board.ravel(), 256, [0, 256])
plt.show()

total.append(board)
board = cv2.GaussianBlur(board, (3, 3), 0)
print('GaussianBlur')
plt.hist(board.ravel(), 256, [0, 256], color='black')
plt.show()

total.append(board)
_, board = cv2.threshold(board, 60, 255, cv2.THRESH_BINARY_INV)
print('threshold')
plt.hist(board.ravel(), 256, [0, 256], color='black')
plt.show()

total.append(board)
plt.imshow(np.hstack(total))
str_board = pytesseract.image_to_string(board)
print(str_board)
# Out:
# basic
# gray
# GaussianBlur
# threshold
# Avs2

# %%
filename = 'video/image (21).jpg'
total = []

img=cv2.imread(filename)

board=img[:25,1550:1905]
length = board.shape[1]
board=board[:,5:int(length*0.21)]

sharpening_1 = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])
board = cv2.filter2D(board, -1, sharpening_1)
print(pytesseract.image_to_string(board))
plt.imshow(board)
plt.show()

fx=4
fy=4
board=cv2.resize(board, dsize=(0,0), fx=fx,fy=fy)


board = cv2.cvtColor(board, cv2.COLOR_RGB2GRAY)
print(pytesseract.image_to_string(board))

# sharpening_1 = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])
# board = cv2.filter2D(board, -1, sharpening_1)
plt.imshow(board)
plt.show()

kernel = np.ones((3,3),np.uint8)



# board = cv2.morphologyEx(board, cv2.MORPH_CLOSE, kernel, iterations=1)

plt.imshow(board)
plt.show()

total.append(board)
board = cv2.GaussianBlur(board, (3, 3), 0)
total.append(board)
_, board = cv2.threshold(board, 0, 255,  cv2.THRESH_OTSU)
print(pytesseract.image_to_string(board))
# board = cv2.erode(board,kernel,iterations = 2)
# board = cv2.dilate(board,kernel,iterations = 4)
# board = cv2.erode(board,kernel,iterations = 2)


plt.imshow(board)
plt.show()

total.append(board)
plt.imshow(np.hstack(total))
print(pytesseract.image_to_string(board))
# Out:
# 16vs 18
# 16 vs 18
# 16 vs 18
# 16 vs 18

# %%
filename = 'video/image (1).jpg'
img=cv2.imread(filename,0)

# 부분 자르기
board=img[:25,1550:1905]
length = board.shape[1]
board=board[:,5:int(length*0.21)]
print(pytesseract.image_to_string(board))
plt.imshow(board)
plt.show()

# 사진 크기 키우기
fx=4
fy=4
board=cv2.resize(board, dsize=(0,0), fx=fx,fy=fy)
kernel = np.ones((3,3),np.uint8)

board = cv2.GaussianBlur(board, (3, 3), 0)
plt.imshow(board)
plt.show()
print(pytesseract.image_to_string(board))
# kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7, 7))
# board = cv2.morphologyEx(board, cv2.MORPH_TOPHAT, kernel)
# plt.imshow(board)
# plt.show()
_, board = cv2.threshold(board, 0, 250, cv2.THRESH_OTSU)
plt.imshow(board)
plt.show()
print(pytesseract.image_to_string(board))
board = cv2.dilate(board, kernel)
_, board = cv2.threshold(board, 0, 250, cv2.THRESH_BINARY_INV)
cv2.imwrite('agfwrgr.jpg', board)

plt.imshow(board)
plt.show()
print(pytesseract.image_to_string(board))
# Out:
# VAY)
# 32 vs 23
# 32 vs 23
# 32 vs 23
